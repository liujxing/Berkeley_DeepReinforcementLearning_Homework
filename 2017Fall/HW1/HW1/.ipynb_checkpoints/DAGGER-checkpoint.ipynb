# %%
"""
Code to load an expert policy and generate roll-out data for behavioral cloning.
Example usage:
    python run_expert.py experts/Humanoid-v1.pkl Humanoid-v1 --render \
            --num_rollouts 20

Author of this script and included expert policies: Jonathan Ho (hoj@openai.com)
"""

import pickle
import tensorflow as tf
import numpy as np
import tf_util
import gym
import load_policy

# %%
import argparse
parser = argparse.ArgumentParser()
parser.add_argument('expert_policy_file', type=str)
parser.add_argument('envname', type=str)
parser.add_argument('--render', action='store_true')
parser.add_argument("--max_timesteps", type=int)
parser.add_argument('--num_rollouts', type=int, default=20,
                    help='Number of expert roll outs')
#args = parser.parse_args(["experts/Humanoid-v1.pkl", "Humanoid-v1", "--render", "--num_rollouts", "200"])
args = parser.parse_args(["experts/Humanoid-v1.pkl", "Humanoid-v1", "--num_rollouts", "20"])
#args = parser.parse_args(["experts/Reacher-v1.pkl", "Reacher-v1", "--render", "--num_rollouts", "20"])
#args = parser.parse_args(["experts/Reacher-v1.pkl", "Reacher-v1", "--num_rollouts", "20000"])
#args = parser.parse_args(["experts/Hopper-v1.pkl", "Hopper-v1", "--render", "--num_rollouts", "20"])
#args = parser.parse_args(["experts/Hopper-v1.pkl", "Hopper-v1", "--num_rollouts", "200"])
#args = parser.parse_args(["experts/Walker2d-v1.pkl", "Walker2d-v1", "--render", "--num_rollouts", "20"])
#args = parser.parse_args(["experts/Walker2d-v1.pkl", "Walker2d-v1", "--num_rollouts", "200"])

# %%
print('loading and building expert policy')
policy_fn = load_policy.load_policy(args.expert_policy_file)
# Out:
# loading and building expert policy
# ('obs', (1, 376), (1, 376))

# %% [markdown]
# **Create Initial Training Data for Clone**

# %%
print('loaded and built')

with tf.Session():
    tf_util.initialize()

    import gym
    env = gym.make(args.envname)  
    print("The observation space for this environment:", env.observation_space)
    print("The action space for this environment:", env.action_space)
    max_steps = args.max_timesteps or env.spec.timestep_limit 

    returns = []
    observations = []
    actions = []
    for i in range(50):
        print('iter', i)
        obs = env.reset()
        done = False
        totalr = 0.
        steps = 0
        while not done:
            action = policy_fn(obs[None,:])
            observations.append(obs)
            actions.append(action)
            obs, r, done, _ = env.step(action) 
            #env.render()
            totalr += r
            steps += 1
            if steps % 100 == 0: print("%i/%i"%(steps, max_steps))
            if steps >= max_steps:
                break
        returns.append(totalr)

    print('returns', returns)
    print('mean return', np.mean(returns))
    print('std of return', np.std(returns))

    expert_data = {'observations': np.array(observations), 
                   'actions': np.array(actions)}
# Out:
# loaded and built
# [2017-03-27 23:24:32,651] Making new env: Humanoid-v1
# ('The observation space for this environment:', Box(376,))
# ('The action space for this environment:', Box(17,))
# ('iter', 0)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 1)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 2)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 3)
# 100/1000
# 200/1000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-2cf3dbd993e4> in <module>()
#      23             observations.append(obs)
#      24             actions.append(action)
# ---> 25             obs, r, done, _ = env.step(action)
#      26             #env.render()
#      27             totalr += r
#
# /Users/liujxing/anaconda/lib/python2.7/site-packages/gym/core.pyc in step(self, action)
#      97             info (dict): contains auxiliary diagnostic information (helpful for debugging, and sometimes learning)
#      98         """
# ---> 99         return self._step(action)
#     100
#     101     def reset(self):
#
# /Users/liujxing/anaconda/lib/python2.7/site-packages/gym/wrappers/time_limit.pyc in _step(self, action)
#      34     def _step(self, action):
#      35         assert self._episode_started_at is not None, "Cannot call env.step() before calling reset()"
# ---> 36         observation, reward, done, info = self.env.step(action)
#      37         self._elapsed_steps += 1
#      38
#
# /Users/liujxing/anaconda/lib/python2.7/site-packages/gym/core.pyc in step(self, action)
#      97             info (dict): contains auxiliary diagnostic information (helpful for debugging, and sometimes learning)
#      98         """
# ---> 99         return self._step(action)
#     100
#     101     def reset(self):
#
# /Users/liujxing/anaconda/lib/python2.7/site-packages/gym/envs/mujoco/humanoid.pyc in _step(self, a)
#      23
#      24     def _step(self, a):
# ---> 25         pos_before = mass_center(self.model)
#      26         self.do_simulation(a, self.frame_skip)
#      27         pos_after = mass_center(self.model)
#
# /Users/liujxing/anaconda/lib/python2.7/site-packages/gym/envs/mujoco/humanoid.pyc in mass_center(model)
#       6     mass = model.body_mass
#       7     xpos = model.data.xipos
# ----> 8     return (np.sum(mass * xpos, 0) / np.sum(mass))[0]
#       9
#      10 class HumanoidEnv(mujoco_env.MujocoEnv, utils.EzPickle):
#
# /Users/liujxing/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in sum(a, axis, dtype, out, keepdims)
#    1831     if keepdims is not np._NoValue:
#    1832         kwargs['keepdims'] = keepdims
# -> 1833     if isinstance(a, _gentype):
#    1834         res = _sum_(a)
#    1835         if out is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# **Perform Initial Fit of Neural Network With Data From Expert Policy**

# %%
import keras
from keras.layers import Dense
from keras.models import Sequential, load_model
# Out:
# Using TensorFlow backend.

# %%
width_dense = 1000

# %%
model = Sequential()
model.add(Dense(width_dense, input_shape=env.observation_space.shape, activation="relu"))
model.add(Dense(width_dense, activation="relu"))
model.add(Dense(np.prod(env.action_space.shape)))

# %%
model.compile(loss='mse', optimizer='adam')

# %%
model.fit(x = expert_data["observations"], y = np.squeeze(expert_data["actions"]), nb_epoch=50, verbose=2)
# Out:
# Epoch 1/50
# 55s - loss: 7.1993
# Epoch 2/50
# 54s - loss: 0.1904
# Epoch 3/50
# 54s - loss: 0.1305
# Epoch 4/50
# 54s - loss: 0.1011
# Epoch 5/50
# 54s - loss: 0.0942
# Epoch 6/50
# 54s - loss: 0.0828
# Epoch 7/50
# 57s - loss: 0.0735
# Epoch 8/50
# 58s - loss: 0.0712
# Epoch 9/50
# 61s - loss: 0.0654
# Epoch 10/50
# 67s - loss: 0.0601
# Epoch 11/50
# 61s - loss: 0.0551
# Epoch 12/50
# 57s - loss: 0.0522
# Epoch 13/50
# 75s - loss: 0.0498
# Epoch 14/50
# 66s - loss: 0.0469
# Epoch 15/50
# 69s - loss: 0.0458
# Epoch 16/50
# 61s - loss: 0.0433
# Epoch 17/50
# 65s - loss: 0.0421
# Epoch 18/50
# 71s - loss: 0.0414
# Epoch 19/50
# 60s - loss: 0.0398
# Epoch 20/50
# 62s - loss: 0.0396
# Epoch 21/50
# 70s - loss: 0.0378
# Epoch 22/50
# 84s - loss: 0.0386
# Epoch 23/50
# 83s - loss: 0.0371
# Epoch 24/50
# 62s - loss: 0.0363
# Epoch 25/50
# 68s - loss: 0.0360
# Epoch 26/50
# 78s - loss: 0.0353
# Epoch 27/50
# 61s - loss: 0.0346
# Epoch 28/50
# 64s - loss: 0.0340
# Epoch 29/50
# 70s - loss: 0.0335
# Epoch 30/50
# 81s - loss: 0.0335
# Epoch 31/50
# 69s - loss: 0.0334
# Epoch 32/50
# 60s - loss: 0.0332
# Epoch 33/50
# 77s - loss: 0.0324
# Epoch 34/50
# 60s - loss: 0.0318
# Epoch 35/50
# 64s - loss: 0.0315
# Epoch 36/50
# 63s - loss: 0.0315
# Epoch 37/50
# 72s - loss: 0.0307
# Epoch 38/50
# 64s - loss: 0.0303
# Epoch 39/50
# 61s - loss: 0.0303
# Epoch 40/50
# 64s - loss: 0.0301
# Epoch 41/50
# 63s - loss: 0.0301
# Epoch 42/50
# 64s - loss: 0.0299
# Epoch 43/50
# 63s - loss: 0.0293
# Epoch 44/50
# 65s - loss: 0.0291
# Epoch 45/50
# 63s - loss: 0.0291
# Epoch 46/50
# 62s - loss: 0.0286
# Epoch 47/50
# 61s - loss: 0.0289
# Epoch 48/50
# 54s - loss: 0.0290
# Epoch 49/50
# 64s - loss: 0.0281
# Epoch 50/50
# 59s - loss: 0.0284

# %% [markdown]
# **Check the Behaviour of the Clone**

# %%
returns = []
observations = []
actions = []
for i in range(10):
    print('iter', i)
    obs = env.reset()
    done = False
    totalr = 0.
    steps = 0
    #while True:
    while not done:
        action = model.predict(obs[None,:]) 
        observations.append(obs)
        actions.append(action)
        obs, r, done, _ = env.step(action)
        totalr += r
        steps += 1
        env.render()
        if steps % 100 == 0: print("%i/%i"%(steps, max_steps))
        if steps >= max_steps:
            break
    returns.append(totalr)
    

print('returns', returns)
print('mean return', np.mean(returns))
print('std of return', np.std(returns))
# Out:
# ('iter', 0)
# 100/1000
# ('iter', 1)
# 100/1000
# 200/1000
# ('iter', 2)
# 100/1000
# 200/1000
# ('iter', 3)
# 100/1000
# 200/1000
# ('iter', 4)
# 100/1000
# ('iter', 5)
# 100/1000
# ('iter', 6)
# ('iter', 7)
# 100/1000
# 200/1000
# 300/1000
# ('iter', 8)
# 100/1000
# 200/1000
# 300/1000
# ('iter', 9)
# 100/1000
# 200/1000
# ('returns', [829.57438906331629, 1621.0355389772174, 1943.0625146717084, 1807.0657725372907, 836.75772165303476, 829.80933578189911, 549.74161722477004, 3738.062344596513, 3425.3628627787934, 2311.8072435051022])
# ('mean return', 1789.2279340789646)
# ('std of return', 1052.8627145099747)

# %%
model.save("Test.h5")

# %% [markdown]
# **Use DAGGER to Generate Data and Re-Training**

# %%
returns = []
observations = []
actions = []
# generate 10 roll-out of new training data and aggregate to the old training data
for i in range(1):
    print('iter', i)
    obs = env.reset()
    done = False
    steps = 0
    while not done:
        action = model.predict(obs[None,:])
        observations.append(obs)
        with tf.Session():
            actions.append(policy_fn(obs[None,:])) # use the expert policy to add the action as y
        actions.append(action) # use the clone policy to perform the action
        obs, r, done, _ = env.step(action) 
        steps += 1
        if steps % 100 == 0: print("%i/%i"%(steps, max_steps))
        if steps >= max_steps:
            break
expert_data["observations"] = np.concatenate((expert_data["observations"], np.array(observations)))
expert_data["actions"] = np.concatenate((expert_data["actions"], np.array(actions)))
model.fit(x = expert_data["observations"], y = np.squeeze(expert_data["actions"]), nb_epoch=5, verbose=10) # perform 5 epochs of training

# %%
for ind_cycle in range(30):
    print("Number of cycle: %d/%d" %(ind_cycle, 30))
    returns = []
    observations = []
    actions = []
    # generate 10 roll-out of new training data and aggregate to the old training data
    for i in range(20):
        print('iter', i)
        obs = env.reset()
        done = False
        steps = 0
        while not done:
            action = model.predict(obs[None,:])
            observations.append(obs)
            with tf.Session():
                actions.append(policy_fn(obs[None,:])) # use the expert policy to add the action as y
            obs, r, done, _ = env.step(action) # use the clone policy to perform the action
            steps += 1
            if steps % 100 == 0: print("%i/%i"%(steps, max_steps))
            if steps >= max_steps:
                break
    expert_data["observations"] = np.concatenate((expert_data["observations"], np.array(observations)))
    expert_data["actions"] = np.concatenate((expert_data["actions"], np.array(actions)))
    model.fit(x = expert_data["observations"], y = np.squeeze(expert_data["actions"]), nb_epoch=10, verbose=2) # perform training on updated data
# Out:
# Number of cycle: 0/30
# ('iter', 0)
# ('iter', 1)
# ('iter', 2)
# 100/1000
# ('iter', 3)
# 100/1000
# ('iter', 4)
# 100/1000
# 200/1000
# ('iter', 5)
# ('iter', 6)
# ('iter', 7)
# 100/1000
# ('iter', 8)
# 100/1000
# 200/1000
# ('iter', 9)
# 100/1000
# ('iter', 10)
# 100/1000
# 200/1000
# 300/1000
# ('iter', 11)
# 100/1000
# ('iter', 12)
# 100/1000
# 200/1000
# ('iter', 13)
# ('iter', 14)
# ('iter', 15)
# ('iter', 16)
# 100/1000
# 200/1000
# 300/1000
# ('iter', 17)
# 100/1000
# 200/1000
# ('iter', 18)
# 100/1000
# 200/1000
# 300/1000
# ('iter', 19)
# 100/1000
# Epoch 1/10
# 65s - loss: 0.0428
# Epoch 2/10
# 68s - loss: 0.0387
# Epoch 3/10
# 67s - loss: 0.0380
# Epoch 4/10
# 63s - loss: 0.0374
# Epoch 5/10
# 59s - loss: 0.0361
# Epoch 6/10
# 56s - loss: 0.0355
# Epoch 7/10
# 56s - loss: 0.0352
# Epoch 8/10
# 57s - loss: 0.0346
# Epoch 9/10
# 56s - loss: 0.0346
# Epoch 10/10
# 56s - loss: 0.0340
# Number of cycle: 1/30
# ('iter', 0)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# ('iter', 1)
# 100/1000
# ('iter', 2)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# ('iter', 3)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 4)
# 100/1000
# ('iter', 5)
# ('iter', 6)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 7)
# ('iter', 8)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 9)
# 100/1000
# 200/1000
# ('iter', 10)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 11)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# ('iter', 12)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 13)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# ('iter', 14)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 15)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# ('iter', 16)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# ('iter', 17)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 18)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 19)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# Epoch 1/10
# 72s - loss: 0.0501
# Epoch 2/10
# 71s - loss: 0.0447
# Epoch 3/10
# 71s - loss: 0.0431
# Epoch 4/10
# 71s - loss: 0.0440
# Epoch 5/10
# 72s - loss: 0.0413
# Epoch 6/10
# 71s - loss: 0.0419
# Epoch 7/10
# 71s - loss: 0.0406
# Epoch 8/10
# 70s - loss: 0.0403
# Epoch 9/10
# 70s - loss: 0.0397
# Epoch 10/10
# 71s - loss: 0.0393
# Number of cycle: 2/30
# ('iter', 0)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 1)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 2)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 3)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 4)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 5)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 6)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 7)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 8)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 9)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 10)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 11)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 12)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 13)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# ('iter', 14)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 15)
# ('iter', 16)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 17)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 18)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 19)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# Epoch 1/10
# 91s - loss: 0.0429
# Epoch 2/10
# 91s - loss: 0.0427
# Epoch 3/10
# 91s - loss: 0.0419
# Epoch 4/10
# 93s - loss: 0.0405
# Epoch 5/10
# 92s - loss: 0.0400
# Epoch 6/10
# 91s - loss: 0.0398
# Epoch 7/10
# 91s - loss: 0.0394
# Epoch 8/10
# 91s - loss: 0.0388
# Epoch 9/10
# 92s - loss: 0.0385
# Epoch 10/10
# 91s - loss: 0.0387
# Number of cycle: 3/30
# ('iter', 0)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 1)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 2)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 3)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 4)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 5)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 6)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 7)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 8)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 9)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 10)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 11)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 12)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 13)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 14)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 15)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 16)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 17)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 18)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 19)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# Epoch 1/10
# 113s - loss: 0.0381
# Epoch 2/10
# 114s - loss: 0.0376
# Epoch 3/10
# 114s - loss: 0.0371
# Epoch 4/10
# 114s - loss: 0.0370
# Epoch 5/10
# 114s - loss: 0.0367
# Epoch 6/10
# 114s - loss: 0.0362
# Epoch 7/10
# 114s - loss: 0.0358
# Epoch 8/10
# 114s - loss: 0.0360
# Epoch 9/10
# 114s - loss: 0.0351
# Epoch 10/10
# 117s - loss: 0.0351
# Number of cycle: 4/30
# ('iter', 0)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 1)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 2)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 3)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 4)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 5)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 6)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# 1000/1000
# ('iter', 7)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-b2b379378f8d> in <module>()
#      14             observations.append(obs)
#      15             with tf.Session():
# ---> 16                 actions.append(policy_fn(obs[None,:])) # use the expert policy to add the action as y
#      17             obs, r, done, _ = env.step(action) # use the clone policy to perform the action
#      18             steps += 1
#
# /Users/liujxing/Desktop/Deep_Reinforcement_Learning/HW/HW1/HW1/tf_util.pyc in <lambda>(*inputs)
#     219     else:
#     220         f = _Function(inputs, [outputs], updates, givens=givens)
# --> 221         return lambda *inputs : f(*inputs)[0]
#     222
#     223 class _Function(object):
#
# /Users/liujxing/Desktop/Deep_Reinforcement_Learning/HW/HW1/HW1/tf_util.pyc in __call__(self, *inputvals)
#     234         feed_dict = dict(zip(self.inputs, inputvals))
#     235         feed_dict.update(self.givens)
# --> 236         results = get_session().run(self.outputs_update, feed_dict=feed_dict)[:-1]
#     237         if self.check_nan:
#     238             if any(np.isnan(r).any() for r in results):
#
# /Users/liujxing/anaconda/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     715     try:
#     716       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 717                          run_metadata_ptr)
#     718       if run_metadata:
#     719         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/liujxing/anaconda/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     913     if final_fetches or final_targets:
#     914       results = self._do_run(handle, final_targets, final_fetches,
# --> 915                              feed_dict_string, options, run_metadata)
#     916     else:
#     917       results = []
#
# /Users/liujxing/anaconda/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#     963     if handle is None:
#     964       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# --> 965                            target_list, options, run_metadata)
#     966     else:
#     967       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /Users/liujxing/anaconda/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#     970   def _do_call(self, fn, *args):
#     971     try:
# --> 972       return fn(*args)
#     973     except errors.OpError as e:
#     974       message = compat.as_text(e.message)
#
# /Users/liujxing/anaconda/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#     948                 run_metadata):
#     949       # Ensure any changes to the graph are reflected in the runtime.
# --> 950       self._extend_graph()
#     951       with errors.raise_exception_on_not_ok_status() as status:
#     952         return tf_session.TF_Run(session, options,
#
# /Users/liujxing/anaconda/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _extend_graph(self)
#     992         graph_def, self._current_version = self._graph._as_graph_def(
#     993             from_version=self._current_version,
# --> 994             add_shapes=self._add_shapes)
#     995         # pylint: enable=protected-access
#     996
#
# /Users/liujxing/anaconda/lib/python2.7/site-packages/tensorflow/python/framework/ops.pyc in _as_graph_def(self, from_version, add_shapes)
#    2204         op = self._nodes_by_id[op_id]
#    2205         if from_version is None or op_id > from_version:
# -> 2206           graph.node.extend([op.node_def])
#    2207           if op.outputs and add_shapes:
#    2208             assert "_output_shapes" not in graph.node[-1].attr
#
# /Users/liujxing/anaconda/lib/python2.7/site-packages/google/protobuf/internal/containers.pyc in extend(self, elem_seq)
#     387       new_element = message_class()
#     388       new_element._SetListener(listener)
# --> 389       new_element.MergeFrom(message)
#     390       values.append(new_element)
#     391     listener.Modified()
#
# /Users/liujxing/anaconda/lib/python2.7/site-packages/google/protobuf/internal/python_message.pyc in MergeFrom(self, msg)
#    1240           field_value = field._default_constructor(self)
#    1241           fields[field] = field_value
# -> 1242         field_value.MergeFrom(value)
#    1243       elif field.cpp_type == CPPTYPE_MESSAGE:
#    1244         if value._is_present_in_parent:
#
# /Users/liujxing/anaconda/lib/python2.7/site-packages/google/protobuf/internal/containers.pyc in MergeFrom(self, other)
#     599       if key in self:
#     600         del self[key]
# --> 601       self[key].CopyFrom(other[key])
#     602     # self._message_listener.Modified() not required here, because
#     603     # mutations to submessages already propagate.
#
# /Users/liujxing/anaconda/lib/python2.7/site-packages/google/protobuf/message.pyc in CopyFrom(self, other_msg)
#     116       return
#     117     self.Clear()
# --> 118     self.MergeFrom(other_msg)
#     119
#     120   def Clear(self):
#
# /Users/liujxing/anaconda/lib/python2.7/site-packages/google/protobuf/internal/python_message.pyc in MergeFrom(self, msg)
#    1248             field_value = field._default_constructor(self)
#    1249             fields[field] = field_value
# -> 1250           field_value.MergeFrom(value)
#    1251       else:
#    1252         self._fields[field] = value
#
# /Users/liujxing/anaconda/lib/python2.7/site-packages/google/protobuf/internal/python_message.pyc in MergeFrom(self, msg)
#    1229
#    1230     assert msg is not self
# -> 1231     self._Modified()
#    1232
#    1233     fields = self._fields
#
# /Users/liujxing/anaconda/lib/python2.7/site-packages/google/protobuf/internal/python_message.pyc in Modified(self)
#    1347       self._listener_for_children.dirty = True
#    1348       self._is_present_in_parent = True
# -> 1349       self._listener.Modified()
#    1350
#    1351   def _UpdateOneofState(self, field):
#
# /Users/liujxing/anaconda/lib/python2.7/site-packages/google/protobuf/internal/python_message.pyc in Modified(self)
#    1427     try:
#    1428       self._parent_message_weakref._UpdateOneofState(self._field)
# -> 1429       super(_OneofListener, self).Modified()
#    1430     except ReferenceError:
#    1431       pass
#
# KeyboardInterrupt:

# %%
model.save("Humanoid_DAGGER.h5")

# %% [markdown]
# **Model Performance After DAGGER**

# %%
from keras.models import load_model

# %%
model = load_model("Humanoid_DAGGER.h5")

# %%
returns = []
observations = []
actions = []
for i in range(10):
    print('iter', i)
    env = gym.make(args.envname)  
    obs = env.reset()
    done = False
    totalr = 0.
    steps = 0
    #while True:
    while not done:
        action = model.predict(obs[None,:]) 
        observations.append(obs)
        actions.append(action)
        obs, r, done, _ = env.step(action)
        totalr += r
        steps += 1
        env.render()
        if steps % 100 == 0: print("%i/%i"%(steps, max_steps))
        if steps >= max_steps:
            break
    returns.append(totalr)
    

print('returns', returns)
print('mean return', np.mean(returns))
print('std of return', np.std(returns))
# Out:
# [2017-03-27 23:24:57,461] Making new env: Humanoid-v1
# ('iter', 0)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# [2017-03-27 23:25:08,755] Making new env: Humanoid-v1
# 1000/1000
# ('iter', 1)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# [2017-03-27 23:25:15,741] Making new env: Humanoid-v1
# 1000/1000
# ('iter', 2)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# [2017-03-27 23:25:24,325] Making new env: Humanoid-v1
# 1000/1000
# ('iter', 3)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# 700/1000
# 800/1000
# 900/1000
# [2017-03-27 23:25:33,313] Making new env: Humanoid-v1
# 1000/1000
# ('iter', 4)
# 100/1000
# 200/1000
# 300/1000
# 400/1000
# 500/1000
# 600/1000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-ccef94b6e101> in <module>()
#      11     #while True:
#      12     while not done:
# ---> 13         action = model.predict(obs[None,:])
#      14         observations.append(obs)
#      15         actions.append(action)
#
# /Users/liujxing/anaconda/lib/python2.7/site-packages/keras/models.pyc in predict(self, x, batch_size, verbose)
#     701         if self.model is None:
#     702             self.build()
# --> 703         return self.model.predict(x, batch_size=batch_size, verbose=verbose)
#     704
#     705     def predict_on_batch(self, x):
#
# /Users/liujxing/anaconda/lib/python2.7/site-packages/keras/engine/training.pyc in predict(self, x, batch_size, verbose)
#    1182         f = self.predict_function
#    1183         return self._predict_loop(f, ins,
# -> 1184                                   batch_size=batch_size, verbose=verbose)
#    1185
#    1186     def train_on_batch(self, x, y,
#
# /Users/liujxing/anaconda/lib/python2.7/site-packages/keras/engine/training.pyc in _predict_loop(self, f, ins, batch_size, verbose)
#     878                 ins_batch = slice_X(ins, batch_ids)
#     879
# --> 880             batch_outs = f(ins_batch)
#     881             if type(batch_outs) != list:
#     882                 batch_outs = [batch_outs]
#
# /Users/liujxing/anaconda/lib/python2.7/site-packages/keras/backend/tensorflow_backend.pyc in __call__(self, inputs)
#    1094             feed_dict[tensor] = value
#    1095         session = get_session()
# -> 1096         updated = session.run(self.outputs + [self.updates_op], feed_dict=feed_dict)
#    1097         return updated[:len(self.outputs)]
#    1098
#
# /Users/liujxing/anaconda/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     715     try:
#     716       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 717                          run_metadata_ptr)
#     718       if run_metadata:
#     719         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/liujxing/anaconda/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     895           if not self.graph.is_feedable(subfeed_t):
#     896             raise ValueError('Tensor %s may not be fed.' % subfeed_t)
# --> 897           subfeed_name = compat.as_bytes(subfeed_t.name)
#     898           feed_dict_string[subfeed_name] = np_val
#     899           feed_map[subfeed_name] = (subfeed_t, subfeed_val)
#
# /Users/liujxing/anaconda/lib/python2.7/site-packages/tensorflow/python/framework/ops.pyc in name(self)
#     316   def name(self):
#     317     """The string name of this tensor."""
# --> 318     if not self._op.name:
#     319       raise ValueError("Operation was not named: %s" % self._op)
#     320     return "%s:%d" % (self._op.name, self._value_index)
#
# /Users/liujxing/anaconda/lib/python2.7/site-packages/tensorflow/python/framework/ops.pyc in name(self)
#    1349   def name(self):
#    1350     """The full name of this operation."""
# -> 1351     return self._node_def.name
#    1352
#    1353   @property
#
# /Users/liujxing/anaconda/lib/python2.7/site-packages/google/protobuf/internal/python_message.pyc in getter(self)
#     657     # TODO(protobuf-team): This may be broken since there may not be
#     658     # default_value.  Combine with has_default_value somehow.
# --> 659     return self._fields.get(field, default_value)
#     660   getter.__module__ = None
#     661   getter.__doc__ = 'Getter for %s.' % proto_field_name
#
# KeyboardInterrupt:
